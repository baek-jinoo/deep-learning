# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:37, 828KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
### Your code here
import collections
import math
import random
import sys

def discard_prob(frequency, threshold):
    return max(1 - math.sqrt(threshold / frequency), 0.0)

def subsampling(int_words, threshold):
    words_length = float(len(int_words))
    
    counter = collections.Counter(int_words)
    int_word_to_discard_probs = {int_word: discard_prob(count/words_length, threshold) for int_word, count in counter.items()}
    return [int_word for int_word in int_words if int_word_to_discard_probs[int_word] < random.random()]
    
train_words = subsampling(int_words, 1e-5)
print("Total words: {}".format(len(int_words)))
print("Unique words: {}".format(len(set(int_words))))
print("Total train_words: {}".format(len(train_words)))
print("Unique train_words: {}".format(len(set(train_words))))
# Out:
# Total words: 16680599
# Unique words: 63641
# Total train_words: 4626437
# Unique train_words: 63641

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    r = random.randint(1, window_size + 1)
    start = max(0, idx-r)
    pre = words[start:idx]
    end = idx + 1 + r
    post = words[idx+1:end]
    return list(set(pre + post))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=(None))
    labels = tf.placeholder(tf.int32, shape=(None, None))

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform(shape=(n_vocab, n_embedding), minval=-1, maxval=1))
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.random_normal([n_vocab, n_embedding], stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros([n_vocab]))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights=softmax_w,
                                      biases=softmax_b,
                                      labels=labels,
                                      inputs=embed,
                                      num_sampled=n_sampled,
                                      num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/embedding_dlnd/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-16-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.7477 0.0365 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6628 0.0285 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5823 0.0285 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6949 0.0282 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.6012 0.0280 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.6117 0.0282 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.6190 0.0284 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.6139 0.0282 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5098 0.0285 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4839 0.0282 sec/batch
# Nearest to years: jeweled, perfection, tempted, bentine, ant, debuting, everything, rhein,
# Nearest to had: telencephalon, misinterpreted, newsreel, colony, timothy, glasgow, wba, fumimaro,
# Nearest to these: holstein, nimitz, seeks, notations, psa, uyghur, werewolf, uncensored,
# Nearest to all: goblets, trend, modicum, azawakh, triumphant, heywood, cyanides, recently,
# Nearest to most: supporter, responsiveness, vodun, massimo, rain, arts, meany, southend,
# Nearest to so: ripuarian, wmo, npd, fart, winners, raaf, smelter, infrastructure,
# Nearest to this: greeks, fidelity, manuscript, ebenezer, baffling, acorns, calc, ignites,
# Nearest to states: mile, wba, quasar, winer, dt, bor, devastate, tempest,
# Nearest to police: rectifier, sweeps, durkheim, wyndham, bayley, offeror, dim, rtf,
# Nearest to brother: applause, cofinal, widower, sumus, bullets, reconstruction, digging, matthias,
# Nearest to paris: expressionist, inpatient, inspirational, commodores, adjusted, protolanguage, edgerton, kg,
# Nearest to derived: ono, thoroughbred, denial, trichechus, protagonists, chilling, byline, traditionally,
# Nearest to animals: inspection, subversion, winston, larnaca, sincerely, bowling, sinusoids, culprit,
# Nearest to award: solicitor, gilmour, stationed, curit, rechristened, riordan, admirers, oration,
# Nearest to applied: losslessly, grievous, iata, mussar, silvio, unsealed, watch, aberystwyth,
# Nearest to additional: raja, miscible, baryogenesis, awakened, learn, scaffold, navarre, leadership,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5662 0.0293 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4344 0.0282 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.4020 0.0282 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.3087 0.0280 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2759 0.0285 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2123 0.0287 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1640 0.0281 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1456 0.0281 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0917 0.0281 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0373 0.0282 sec/batch
# Nearest to years: lists, everything, perfection, jeweled, bentine, rhein, effectively, cent,
# Nearest to had: colony, timothy, misinterpreted, newsreel, telencephalon, glasgow, risks, repertoire,
# Nearest to these: notations, seeks, its, holstein, phase, trench, name, werewolf,
# Nearest to all: considered, trend, triumphant, recently, legitimate, composition, homosexuality, regardless,
# Nearest to most: supporter, arts, rain, vodun, responsiveness, dungeon, state, pass,
# Nearest to so: infrastructure, winners, lack, decimated, yes, ripuarian, explains, entered,
# Nearest to this: greeks, fidelity, going, manuscript, on, ebenezer, discussion, lambda,
# Nearest to states: mile, festival, dt, taking, winer, demands, john, lengths,
# Nearest to police: rectifier, sweeps, understand, wyndham, durkheim, lubricants, excuse, odilo,
# Nearest to brother: applause, cofinal, widower, bullets, reconstruction, matthias, sumus, digging,
# Nearest to paris: expressionist, adjusted, inpatient, opposed, holders, edgerton, commodores, kg,
# Nearest to derived: protagonists, type, thoroughbred, traditionally, ono, denial, calls, colony,
# Nearest to animals: inspection, subversion, winston, article, nature, subsidies, sincerely, goss,
# Nearest to award: solicitor, gilmour, attended, stationed, oration, admirers, curit, freedom,
# Nearest to applied: watch, silvio, losslessly, mussar, grievous, iata, category, hb,
# Nearest to additional: raja, learn, miscible, baryogenesis, leaflets, leadership, oglethorpe, otherwise,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9847 0.0292 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9364 0.0281 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9481 0.0285 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.9263 0.0286 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8516 0.0282 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8673 0.0283 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8406 0.0284 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8300 0.0282 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8459 0.0283 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8391 0.0285 sec/batch
# Nearest to years: perfection, lists, tempted, everything, bentine, jeweled, goodbye, prussia,
# Nearest to had: colony, timothy, glasgow, newsreel, misinterpreted, risks, telencephalon, notified,
# Nearest to these: seeks, notations, holstein, its, phase, nimitz, trench, werewolf,
# Nearest to all: trend, considered, fledgling, triumphant, nationalists, quarrel, heywood, legitimate,
# Nearest to most: supporter, arts, rain, reign, vodun, dungeon, emir, responsiveness,
# Nearest to so: infrastructure, yes, winners, ripuarian, decimated, martial, soil, sees,
# Nearest to this: greeks, fidelity, manuscript, horizontal, going, lambda, situated, agendas,
# Nearest to states: mile, demands, taking, festival, quasar, coup, bor, exacerbated,
# Nearest to police: rectifier, sweeps, understand, excuse, lubricants, fait, spouses, wyndham,
# Nearest to brother: applause, widower, digging, matthias, reconstruction, bullets, cofinal, sumus,
# Nearest to paris: expressionist, adjusted, inpatient, holders, opposed, british, editors, kg,
# Nearest to derived: ono, type, denial, thoroughbred, protagonists, problem, traditionally, saba,
# Nearest to animals: inspection, subversion, winston, article, subsidies, nature, culprit, automobile,
# Nearest to award: attended, admirers, gilmour, solicitor, euro, curit, stationed, orkney,
# Nearest to applied: watch, losslessly, grievous, category, iata, silvio, ceding, mussar,
# Nearest to additional: raja, learn, leadership, miscible, leaflets, awakened, oglethorpe, preparation,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8379 0.0295 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.8224 0.0282 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7707 0.0282 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7606 0.0282 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7751 0.0285 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7258 0.0286 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7351 0.0289 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7531 0.0285 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7293 0.0286 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6953 0.0281 sec/batch
# Nearest to years: tempted, perfection, jeweled, lists, clerics, dwight, zooming, uta,
# Nearest to had: colony, newsreel, glasgow, timothy, notified, misinterpreted, outfield, externally,
# Nearest to these: seeks, notations, holstein, its, obsidian, uyghur, uncensored, phase,
# Nearest to all: fledgling, considered, modicum, trend, heywood, triumphant, quarrel, nationalists,
# Nearest to most: supporter, arts, rain, emir, reign, responsiveness, vodun, massimo,
# Nearest to so: infrastructure, yes, assistants, decimated, martial, sees, winners, ripuarian,
# Nearest to this: fidelity, greeks, manuscript, going, horizontal, tin, alluded, ebenezer,
# Nearest to states: mile, demands, bor, festival, coup, exacerbated, taking, critiques,
# Nearest to police: excuse, rectifier, sweeps, fait, durkheim, spouses, bayley, wyndham,
# Nearest to brother: applause, widower, digging, matthias, reconstruction, bullets, cofinal, girdler,
# Nearest to paris: expressionist, inpatient, adjusted, holders, british, opposed, edgerton, commodores,
# Nearest to derived: ono, denial, thoroughbred, type, venture, calls, usages, arthur,
# Nearest to animals: inspection, subversion, winston, bowling, nature, subsidies, article, culprit,
# Nearest to award: attended, admirers, gilmour, curit, kirby, solicitor, riordan, orkney,
# Nearest to applied: losslessly, watch, newsgroups, iata, grievous, ceding, category, unsealed,
# Nearest to additional: raja, awakened, learn, miscible, oglethorpe, leadership, negotiate, chapel,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.7414 0.0290 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6950 0.0283 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6334 0.0284 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6326 0.0284 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6711 0.0285 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6672 0.0286 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6320 0.0214 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5800 0.0283 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5504 0.0283 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5408 0.0283 sec/batch
# Nearest to years: tempted, zooming, spoil, bentine, clerics, migrant, dwight, perfection,
# Nearest to had: newsreel, colony, glasgow, notified, timothy, bormann, outfield, was,
# Nearest to these: seeks, phase, obsidian, nimitz, its, immanent, psa, notations,
# Nearest to all: fledgling, considered, modicum, heywood, quarrel, goblets, abilene, triumphant,
# Nearest to most: supporter, arts, responsiveness, rain, emir, massimo, reign, presidentially,
# Nearest to so: decimated, martial, assistants, ripuarian, must, speeds, mattress, sees,
# Nearest to this: fidelity, greeks, manuscript, going, horizontal, doing, sopot, tin,
# Nearest to states: bor, mile, coup, quasar, demands, critiques, exacerbated, ratisbon,
# Nearest to police: durkheim, rectifier, sweeps, excuse, bayley, fait, odilo, menelik,
# Nearest to brother: applause, widower, matthias, digging, reconstruction, mashad, girdler, cartographer,
# Nearest to paris: expressionist, inpatient, british, adjusted, holders, tulsa, edgerton, opposed,
# Nearest to derived: ono, type, usages, denial, thoroughbred, traditionally, byline, calls,
# Nearest to animals: inspection, subversion, sinusoids, article, winston, larnaca, nature, huntley,
# Nearest to award: attended, gilmour, admirers, curit, riordan, orkney, fils, zola,
# Nearest to applied: losslessly, newsgroups, grievous, unsealed, iata, aberystwyth, ceding, mindanao,
# Nearest to additional: raja, miscible, learn, awakened, scaffold, preparation, ewangelicko, beaumarchais,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5293 0.0296 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5350 0.0281 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4956 0.0284 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5320 0.0285 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5271 0.0286 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.5148 0.0283 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.5415 0.0282 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4487 0.0293 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4683 0.0282 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4732 0.0281 sec/batch
# Nearest to years: tempted, migrant, spoil, zooming, clerics, regime, bentine, perfection,
# Nearest to had: newsreel, colony, glasgow, bormann, timothy, was, notified, outfield,
# Nearest to these: seeks, phase, obsidian, its, nimitz, companionate, psa, accelerations,
# Nearest to all: fledgling, modicum, considered, heywood, abilene, caput, goblets, trend,
# Nearest to most: supporter, arts, responsiveness, rain, presidentially, rstendamm, vodun, massimo,
# Nearest to so: must, decimated, martial, sees, speeds, assistants, mattress, machined,
# Nearest to this: greeks, fidelity, manuscript, doing, horizontal, tin, going, rab,
# Nearest to states: mile, coup, exacerbated, bor, tonga, quasar, demands, united,
# Nearest to police: durkheim, rectifier, excuse, bayley, sweeps, ranatunga, menelik, fait,
# Nearest to brother: applause, widower, matthias, digging, mashad, reconstruction, zeev, cofinal,
# Nearest to paris: expressionist, inpatient, holders, tulsa, edgerton, adjusted, british, opposed,
# Nearest to derived: type, ono, energy, usages, calls, traditionally, byline, denial,
# Nearest to animals: inspection, subversion, sinusoids, larnaca, nature, huntley, organism, article,
# Nearest to award: attended, gilmour, admirers, curit, goidelic, orkney, kirby, riordan,
# Nearest to applied: losslessly, grievous, unsealed, newsgroups, iata, aberystwyth, mindanao, mussar,
# Nearest to additional: miscible, raja, learn, awakened, computation, scaffold, beaumarchais, preparation,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4568 0.0294 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4367 0.0286 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4930 0.0285 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4540 0.0283 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4471 0.0285 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4626 0.0284 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4156 0.0285 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4363 0.0283 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4326 0.0285 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.4038 0.0284 sec/batch
# Nearest to years: migrant, tempted, zooming, spoil, regime, clerics, perfection, jeweled,
# Nearest to had: newsreel, glasgow, colony, was, bormann, timothy, outfield, lover,
# Nearest to these: seeks, phase, closer, nimitz, its, vastly, uyghur, companionate,
# Nearest to all: fledgling, modicum, considered, heywood, caput, symmetry, sunglasses, surround,
# Nearest to most: responsiveness, supporter, presidentially, arts, rain, vodun, rstendamm, unauthorised,
# Nearest to so: must, speeds, drawback, empirical, sees, spherically, mattress, decimated,
# Nearest to this: greeks, fidelity, doing, tin, manuscript, presented, basses, horizontal,
# Nearest to states: coup, tonga, assistance, exacerbated, pundit, mile, ratisbon, united,
# Nearest to police: menelik, durkheim, ranatunga, bayley, rectifier, excuse, sweeps, spouses,
# Nearest to brother: applause, widower, matthias, digging, mashad, reconstruction, cartographer, blyton,
# Nearest to paris: expressionist, tulsa, inpatient, holders, edgerton, british, opposed, kammu,
# Nearest to derived: type, usages, pyr, energy, ono, traditionally, byline, aes,
# Nearest to animals: inspection, sinusoids, subversion, larnaca, organism, covered, nature, huntley,
# Nearest to award: gilmour, attended, admirers, curit, kirby, riordan, screenplay, cartoons,
# Nearest to applied: losslessly, unsealed, grievous, iata, mindanao, bilinear, mussar, hypothetical,
# Nearest to additional: raja, learn, miscible, computation, awakened, beaumarchais, ewangelicko, scaffold,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.4426 0.0291 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4105 0.0281 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.4138 0.0282 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.4032 0.0282 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4213 0.0282 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3912 0.0286 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4175 0.0284 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.4084 0.0281 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3513 0.0281 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3623 0.0292 sec/batch
# Nearest to years: migrant, tempted, zooming, regime, iaido, clerics, spoil, jeweled,
# Nearest to had: newsreel, was, colony, glasgow, bormann, misinterpreted, timothy, notified,
# Nearest to these: seeks, nimitz, vastly, its, uyghur, companionate, closer, accelerations,
# Nearest to all: modicum, fledgling, considered, caput, heywood, evangelium, arrayed, surround,
# Nearest to most: presidentially, responsiveness, arts, supporter, rain, rstendamm, vodun, unauthorised,
# Nearest to so: must, decimated, spherically, fruitfulness, speeds, drawback, martial, know,
# Nearest to this: greeks, fidelity, tin, doing, manuscript, rab, basses, even,
# Nearest to states: coup, united, pundit, assistance, ratisbon, demands, tonga, exacerbated,
# Nearest to police: menelik, ranatunga, durkheim, bayley, excuse, rectifier, spouses, unpopular,
# Nearest to brother: applause, widower, digging, matthias, mashad, cartographer, blyton, zeev,
# Nearest to paris: expressionist, tulsa, holders, inpatient, edgerton, playfair, british, kammu,
# Nearest to derived: type, usages, pyr, energy, traditionally, aes, multiplying, gospel,
# Nearest to animals: inspection, sinusoids, larnaca, subversion, mammals, humans, testes, nature,
# Nearest to award: gilmour, admirers, curit, attended, screenplay, zola, riordan, goidelic,
# Nearest to applied: losslessly, unsealed, grievous, hypothetical, infirm, mussar, qos, aberystwyth,
# Nearest to additional: raja, learn, miscible, computation, awakened, cameroonian, beaumarchais, baryogenesis,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3926 0.0291 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3000 0.0285 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.4108 0.0287 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3816 0.0286 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3857 0.0282 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3039 0.0283 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3491 0.0283 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3720 0.0283 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2388 0.0283 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3151 0.0286 sec/batch
# Nearest to years: migrant, female, zero, male, infant, tempted, est, clerics,
# Nearest to had: newsreel, was, glasgow, colony, bormann, notified, misinterpreted, outfield,
# Nearest to these: seeks, accelerations, closer, uyghur, companionate, glimpses, wrongful, tiered,
# Nearest to all: modicum, fledgling, evangelium, considered, surround, caput, heywood, abducted,
# Nearest to most: arts, presidentially, responsiveness, rstendamm, supporter, vodun, unauthorised, inx,
# Nearest to so: must, martial, spherically, thatch, decimated, fruitfulness, know, assistants,
# Nearest to this: greeks, fidelity, doing, basses, tin, manuscript, even, precision,
# Nearest to states: coup, pundit, united, demands, ratisbon, exacerbated, assistance, tonga,
# Nearest to police: menelik, ranatunga, bayley, durkheim, excuse, fait, spouses, unpopular,
# Nearest to brother: widower, applause, mashad, matthias, blyton, digging, zeev, skateboarder,
# Nearest to paris: expressionist, tulsa, holders, edgerton, british, les, playfair, de,
# Nearest to derived: type, usages, traditionally, pyr, aes, reduplication, cluniac, multiplying,
# Nearest to animals: inspection, sinusoids, mammals, humans, larnaca, subversion, nature, testes,
# Nearest to award: gilmour, curit, admirers, attended, zola, screenplay, oscars, vh,
# Nearest to applied: losslessly, unsealed, grievous, hypothetical, infirm, mindanao, iata, bilinear,
# Nearest to additional: learn, miscible, raja, computation, beaumarchais, theorizes, baryogenesis, ewangelicko,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3173 0.0295 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3369 0.0282 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3625 0.0138 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2895 0.0282 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2617 0.0283 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2296 0.0283 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2279 0.0285 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2561 0.0286 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2698 0.0282 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2089 0.0282 sec/batch
# Nearest to years: migrant, female, male, zero, est, infant, fertility, tempted,
# Nearest to had: was, newsreel, glasgow, bormann, misinterpreted, outfield, colony, colom,
# Nearest to these: seeks, accelerations, vastly, tiered, closer, glimpses, companionate, uyghur,
# Nearest to all: modicum, fledgling, caput, evangelium, surround, azawakh, hydroelectricity, disinformation,
# Nearest to most: presidentially, responsiveness, arts, vodun, inx, supporter, rstendamm, bnls,
# Nearest to so: spherically, know, fruitfulness, must, assistants, npd, machined, thatch,
# Nearest to this: greeks, fidelity, basses, prebiotic, horizontal, precision, doing, tin,
# Nearest to states: pundit, coup, united, demands, assistance, ratisbon, ixian, critiques,
# Nearest to police: ranatunga, menelik, excuse, bayley, spouses, unpopular, durkheim, rectifier,
# Nearest to brother: applause, widower, mashad, blyton, zeev, mabon, digging, hotham,
# Nearest to paris: expressionist, tulsa, edgerton, les, holders, de, playfair, kammu,
# Nearest to derived: usages, type, traditionally, pyr, reduplication, gospel, aes, saba,
# Nearest to animals: humans, inspection, sinusoids, nature, mammals, larnaca, organism, testes,
# Nearest to award: gilmour, screenplay, curit, nominations, oscars, admirers, zola, attended,
# Nearest to applied: losslessly, unsealed, grievous, infirm, bilinear, mindanao, qos, aberystwyth,
# Nearest to additional: learn, computation, miscible, raja, beaumarchais, baryogenesis, awakened, totschlag,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2801 0.0301 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2421 0.0282 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2244 0.0281 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1357 0.0284 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.2094 0.0285 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.2083 0.0281 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1824 0.0282 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.2083 0.0283 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2287 0.0282 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.2059 0.0284 sec/batch
# Nearest to years: migrant, zero, female, tempted, clerics, infant, male, loftus,
# Nearest to had: was, glasgow, xxiv, outfield, bormann, misinterpreted, newsreel, hoped,
# Nearest to these: seeks, accelerations, brushing, biomass, vastly, closer, companionate, uyghur,
# Nearest to all: modicum, caput, fledgling, evangelium, enumerates, hydroelectricity, symmetry, considered,
# Nearest to most: presidentially, arts, responsiveness, inx, vodun, rstendamm, supporter, bnls,
# Nearest to so: fruitfulness, must, speeds, machined, assistants, thatch, decimated, spherically,
# Nearest to this: greeks, tin, horizontal, basses, even, precision, prebiotic, doing,
# Nearest to states: pundit, united, ixian, assistance, ratisbon, critiques, demands, coup,
# Nearest to police: ranatunga, menelik, bayley, oecd, excuse, spouses, durkheim, unpopular,
# Nearest to brother: applause, widower, mashad, blyton, mabon, zeev, digging, hotham,
# Nearest to paris: expressionist, tulsa, de, les, edgerton, playfair, holders, kammu,
# Nearest to derived: type, traditionally, reduplication, usages, pyr, devoiced, gospel, phonological,
# Nearest to animals: humans, mammals, inspection, nature, sinusoids, larnaca, testes, organism,
# Nearest to award: screenplay, gilmour, curit, oscars, nominations, zola, admirers, vh,
# Nearest to applied: losslessly, unsealed, bilinear, grievous, qos, mindanao, hypothetical, thermionic,
# Nearest to additional: learn, computation, raja, miscible, beaumarchais, baryogenesis, totschlag, theorizes,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.2057 0.0294 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2565 0.0286 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.2293 0.0283 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1866 0.0283 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2332 0.0281 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2121 0.0283 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2128 0.0283 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1715 0.0281 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1598 0.0285 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1872 0.0285 sec/batch
# Nearest to years: migrant, zero, female, infant, male, est, expectancy, mortality,
# Nearest to had: was, glasgow, xxiv, misinterpreted, colom, bormann, outfield, newsreel,
# Nearest to these: seeks, vastly, brushing, biomass, companionate, accelerations, merchants, glimpses,
# Nearest to all: fledgling, evangelium, modicum, caput, surround, symmetry, is, fifth,
# Nearest to most: presidentially, arts, responsiveness, inx, rstendamm, vodun, savannas, supporter,
# Nearest to so: must, majoris, thatch, know, assistants, fruitfulness, npd, spherically,
# Nearest to this: greeks, prebiotic, horizontal, tin, reorient, basses, substituting, precision,
# Nearest to states: united, pundit, coup, ratisbon, ixian, assistance, demands, critiques,
# Nearest to police: ranatunga, menelik, spouses, bayley, durkheim, mahuad, rectifier, excuse,
# Nearest to brother: widower, applause, blyton, mabon, mashad, digging, soon, hotham,
# Nearest to paris: expressionist, tulsa, de, edgerton, les, playfair, holders, ou,
# Nearest to derived: type, reduplication, traditionally, usages, phonological, pyr, devoiced, etymology,
# Nearest to animals: humans, mammals, inspection, nature, testes, organism, spasms, sinusoids,
# Nearest to award: nominations, screenplay, curit, gilmour, oscars, vh, zola, admirers,
# Nearest to applied: losslessly, hypothetical, grievous, bilinear, infirm, unsealed, mindanao, describe,
# Nearest to additional: computation, learn, raja, theorizes, miscible, cuon, baryogenesis, ewangelicko,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2095 0.0293 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.2035 0.0283 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.2337 0.0293 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2239 0.0282 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1474 0.0283 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1206 0.0285 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1713 0.0283 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1480 0.0284 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1917 0.0284 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2395 0.0283 sec/batch
# Nearest to years: migrant, zero, female, infant, male, birth, expectancy, fertility,
# Nearest to had: was, glasgow, bormann, claimed, colom, misinterpreted, xxiv, outfield,
# Nearest to these: seeks, merchants, ambience, vastly, tiered, companionate, brushing, glimpses,
# Nearest to all: evangelium, fledgling, modicum, caput, fifth, abducted, enumerates, disinformation,
# Nearest to most: presidentially, arts, vodun, supporter, rstendamm, inx, travellers, bnls,
# Nearest to so: majoris, know, thatch, fruitfulness, decimated, rebuild, must, patriotic,
# Nearest to this: tin, reorient, greeks, to, prebiotic, on, underscored, fosters,
# Nearest to states: united, pundit, ratisbon, coup, demands, ixian, riverboat, critiques,
# Nearest to police: ranatunga, menelik, spouses, mahuad, excuse, department, verner, ku,
# Nearest to brother: widower, applause, blyton, digging, soon, accidentally, hotham, mabon,
# Nearest to paris: expressionist, tulsa, de, edgerton, les, ou, playfair, holders,
# Nearest to derived: type, usages, reduplication, traditionally, phonological, devoiced, etymology, pyr,
# Nearest to animals: humans, mammals, inspection, nature, testes, larnaca, covered, spasms,
# Nearest to award: nominations, screenplay, awards, oscars, curit, awarded, gilmour, vh,
# Nearest to applied: grievous, mindanao, greenfield, infirm, hypothetical, embodied, losslessly, phalanx,
# Nearest to additional: computation, learn, theorizes, cameroonian, raja, negotiate, miscible, ons,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2261 0.0292 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1740 0.0283 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1780 0.0285 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1736 0.0286 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0343 0.0283 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1717 0.0283 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1809 0.0282 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1562 0.0281 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.2119 0.0066 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1272 0.0285 sec/batch
# Nearest to years: migrant, zero, female, infant, male, fertility, birth, expectancy,
# Nearest to had: was, glasgow, waking, xxiv, colom, claimed, outfield, bormann,
# Nearest to these: seeks, accelerations, brushing, ambience, companionate, phase, suggestibility, glimpses,
# Nearest to all: evangelium, fledgling, modicum, caput, enumerates, is, disinformation, fifth,
# Nearest to most: presidentially, arts, savannas, rstendamm, inx, wojew, vodun, disco,
# Nearest to so: majoris, thatch, must, paraphrased, know, decimated, rebuild, speeds,
# Nearest to this: presented, underscored, precision, accumulated, tin, empiricists, reorient, prebiotic,
# Nearest to states: united, pundit, ratisbon, riverboat, ixian, demands, coup, dt,
# Nearest to police: ranatunga, menelik, excuse, mahuad, spouses, department, bayley, verner,
# Nearest to brother: widower, applause, blyton, accidentally, herself, hotham, mabon, honeybee,
# Nearest to paris: expressionist, tulsa, de, edgerton, les, adjusted, holders, odeon,
# Nearest to derived: reduplication, type, traditionally, usages, phonological, devoiced, aes, arbitrio,
# Nearest to animals: mammals, humans, nature, inspection, testes, mammalia, spasms, larnaca,
# Nearest to award: nominations, awards, oscars, screenplay, curit, gilmour, zola, vh,
# Nearest to applied: grievous, infirm, losslessly, qos, mindanao, embodied, phalanx, unsealed,
# Nearest to additional: computation, learn, theorizes, ons, miscible, ewangelicko, require, cuon,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.1090 0.0297 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.1049 0.0284 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1098 0.0282 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0827 0.0291 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.1065 0.0284 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0825 0.0281 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1247 0.0284 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1426 0.0285 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1440 0.0284 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0708 0.0284 sec/batch
# Nearest to years: migrant, zero, female, male, infant, expectancy, two, fertility,
# Nearest to had: was, outfield, glasgow, colom, xxiv, hoped, waking, bormann,
# Nearest to these: seeks, companionate, brushing, ambience, vastly, suggestibility, accelerations, name,
# Nearest to all: evangelium, modicum, fledgling, is, fifth, disinformation, caput, enumerates,
# Nearest to most: presidentially, inx, wojew, arts, vodun, istrian, savannas, top,
# Nearest to so: rebuild, drags, know, decimated, thatch, paraphrased, majoris, soil,
# Nearest to this: tin, precision, prebiotic, to, reorient, accumulated, greeks, presented,
# Nearest to states: united, pundit, ratisbon, demands, ixian, critiques, lincoln, riverboat,
# Nearest to police: ranatunga, menelik, excuse, mahuad, spouses, bayley, oecd, apolitical,
# Nearest to brother: widower, applause, soon, blyton, honeybee, accidentally, mabon, mashad,
# Nearest to paris: expressionist, de, tulsa, les, edgerton, ou, mapmaker, odeon,
# Nearest to derived: reduplication, type, traditionally, usages, phonological, devoiced, aes, implements,
# Nearest to animals: mammals, humans, nature, inspection, testes, mammalia, spasms, larnaca,
# Nearest to award: nominations, oscars, awards, screenplay, curit, awarded, pressings, emmy,
# Nearest to applied: mindanao, greenfield, embodied, bilinear, qos, grievous, losslessly, infirm,
# Nearest to additional: computation, learn, theorizes, miscible, ons, cuon, raja, require,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0360 0.0293 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0710 0.0283 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0506 0.0281 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0927 0.0283 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.1071 0.0286 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0481 0.0281 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.1026 0.0282 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1075 0.0281 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0642 0.0282 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0771 0.0282 sec/batch
# Nearest to years: migrant, zero, female, expectancy, two, male, est, infant,
# Nearest to had: was, glasgow, bormann, xxiv, hoped, colom, outfield, claimed,
# Nearest to these: seeks, companionate, ambience, brushing, accelerations, vastly, phase, glimpses,
# Nearest to all: evangelium, is, modicum, enumerates, fledgling, fifth, caput, surround,
# Nearest to most: inx, presidentially, vodun, alphabetical, top, sunspot, savannas, raya,
# Nearest to so: must, boil, if, desired, know, spherically, paraphrased, rebuild,
# Nearest to this: tin, to, accumulated, precision, on, reorient, presented, underscored,
# Nearest to states: united, pundit, ratisbon, ixian, lincoln, demands, dt, riverboat,
# Nearest to police: ranatunga, menelik, excuse, mahuad, durkheim, apolitical, spouses, oecd,
# Nearest to brother: widower, applause, soon, blyton, mabon, honeybee, digging, accidentally,
# Nearest to paris: expressionist, tulsa, de, edgerton, mapmaker, les, alessandro, ou,
# Nearest to derived: reduplication, type, traditionally, usages, devoiced, phonological, aes, implements,
# Nearest to animals: mammals, humans, nature, inspection, mammalia, testes, reptiles, spasms,
# Nearest to award: nominations, awards, oscars, screenplay, awarded, curit, impoverished, pressings,
# Nearest to applied: embodied, qos, losslessly, bilinear, greenfield, infirm, describe, mindanao,
# Nearest to additional: computation, learn, theorizes, ons, miscible, require, beaumarchais, raja,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0531 0.0294 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1028 0.0285 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.1113 0.0283 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0668 0.0282 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0906 0.0286 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0758 0.0284 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0929 0.0280 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0945 0.0284 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1066 0.0285 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0660 0.0284 sec/batch
# Nearest to years: zero, migrant, female, expectancy, male, infant, fertility, est,
# Nearest to had: was, bormann, glasgow, colom, soon, outfield, were, soli,
# Nearest to these: companionate, seeks, glimpses, merchants, noteworthy, ambience, desecration, voivodship,
# Nearest to all: evangelium, is, fledgling, modicum, caput, surround, fifth, enumerates,
# Nearest to most: vodun, presidentially, inx, istrian, adherents, savannas, rstendamm, radically,
# Nearest to so: paraphrased, rebuild, majoris, drags, know, boil, thatch, must,
# Nearest to this: tin, to, reorient, precision, on, greeks, accumulated, presented,
# Nearest to states: united, pundit, ratisbon, demands, ixian, thaw, critiques, dt,
# Nearest to police: menelik, ranatunga, apolitical, excuse, mahuad, spouses, department, durkheim,
# Nearest to brother: widower, applause, soon, blyton, digging, honeybee, mabon, smitten,
# Nearest to paris: expressionist, de, tulsa, edgerton, alessandro, mapmaker, nasser, carabineros,
# Nearest to derived: reduplication, usages, type, traditionally, devoiced, phonological, etymology, implements,
# Nearest to animals: mammals, humans, mammalia, nature, inspection, reptiles, testes, striped,
# Nearest to award: nominations, awards, oscars, awarded, curit, impoverished, screenplay, pressings,
# Nearest to applied: embodied, greenfield, distract, infirm, mindanao, qos, biometric, bilinear,
# Nearest to additional: theorizes, computation, cameroonian, preparation, raja, miscible, learn, delocalised,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.1142 0.0294 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0014 0.0284 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0476 0.0283 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.1076 0.0285 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.1049 0.0287 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1307 0.0284 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1689 0.0280 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0446 0.0284 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0746 0.0281 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.1052 0.0280 sec/batch
# Nearest to years: migrant, zero, female, expectancy, male, fertility, infant, est,
# Nearest to had: was, bormann, glasgow, outfield, colom, claimed, his, hoped,
# Nearest to these: companionate, suggestibility, seeks, accelerations, ambience, noteworthy, glimpses, brushing,
# Nearest to all: evangelium, modicum, surround, fledgling, is, enumerates, consummate, caput,
# Nearest to most: vodun, presidentially, inx, istrian, savannas, supporter, arts, bnls,
# Nearest to so: paraphrased, drags, majoris, soil, rebuild, thatch, know, spherically,
# Nearest to this: to, reorient, tin, precision, accumulated, on, presented, substituting,
# Nearest to states: united, ratisbon, pundit, demands, dt, ixian, lincoln, thaw,
# Nearest to police: menelik, department, apolitical, ranatunga, excuse, mahuad, spouses, whack,
# Nearest to brother: widower, applause, soon, blyton, honeybee, sister, hotham, smitten,
# Nearest to paris: expressionist, de, tulsa, mapmaker, alessandro, edgerton, nasser, odeon,
# Nearest to derived: reduplication, usages, type, devoiced, traditionally, phonological, etymology, implements,
# Nearest to animals: mammals, humans, mammalia, reptiles, nature, testes, species, inspection,
# Nearest to award: nominations, awards, oscars, awarded, curit, screenplay, impoverished, emmy,
# Nearest to applied: distract, infirm, greenfield, mindanao, embodied, phalanx, sejm, unsealed,
# Nearest to additional: theorizes, computation, learn, preparation, raja, delocalised, miscible, gprs,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9990 0.0292 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0338 0.0283 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0535 0.0286 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0802 0.0284 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.1172 0.0283 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0757 0.0274 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0432 0.0288 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9954 0.0283 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0379 0.0285 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 4.0097 0.0284 sec/batch
# Nearest to years: migrant, zero, female, expectancy, fertility, male, birth, infant,
# Nearest to had: was, colom, successor, glasgow, outfield, hoped, soon, bormann,
# Nearest to these: companionate, accelerations, glimpses, noteworthy, suggestibility, seeks, ambience, merchants,
# Nearest to all: evangelium, modicum, surround, is, fledgling, consummate, enumerates, fifth,
# Nearest to most: presidentially, istrian, inx, vodun, abbreviated, savannas, such, alphabetical,
# Nearest to so: soil, drags, paraphrased, boil, rebuild, majoris, lyre, know,
# Nearest to this: to, on, substituting, tin, accumulated, precision, their, prebiotic,
# Nearest to states: united, ratisbon, pundit, dt, demands, ixian, pg, lincoln,
# Nearest to police: menelik, ranatunga, department, apolitical, excuse, mahuad, spouses, whack,
# Nearest to brother: widower, soon, applause, sister, honeybee, blyton, smitten, mabon,
# Nearest to paris: expressionist, de, tulsa, mapmaker, nasser, ou, odeon, louvre,
# Nearest to derived: reduplication, type, usages, traditionally, devoiced, phonological, arthur, etymology,
# Nearest to animals: mammals, humans, mammalia, nature, reptiles, inspection, testes, herbivores,
# Nearest to award: nominations, awards, oscars, awarded, curit, screenplay, emmy, impoverished,
# Nearest to applied: greenfield, distract, infirm, embodied, afips, sejm, unsealed, grievous,
# Nearest to additional: theorizes, computation, preparation, delocalised, learn, miscible, raja, gprs,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9885 0.0295 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9467 0.0287 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0256 0.0284 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0422 0.0284 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0416 0.0282 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0252 0.0285 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9362 0.0288 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9861 0.0285 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9523 0.0282 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.0094 0.0281 sec/batch
# Nearest to years: migrant, zero, expectancy, two, female, male, fertility, live,
# Nearest to had: was, outfield, soon, hoped, glasgow, colom, trajkovski, successor,
# Nearest to these: companionate, accelerations, seeks, brushing, suggestibility, noteworthy, ambience, merchants,
# Nearest to all: evangelium, is, modicum, surround, fledgling, enumerates, in, fifth,
# Nearest to most: presidentially, inx, istrian, radically, vodun, alphabetical, saarc, dominated,
# Nearest to so: soil, drags, paraphrased, boil, if, rebuild, know, desired,
# Nearest to this: to, tin, on, precision, accumulated, their, prebiotic, reorient,
# Nearest to states: united, ratisbon, dt, demands, pundit, ixian, lincoln, courts,
# Nearest to police: menelik, department, apolitical, ranatunga, excuse, mahuad, whack, spouses,
# Nearest to brother: widower, soon, applause, honeybee, blyton, sister, smitten, digging,
# Nearest to paris: expressionist, tulsa, mapmaker, de, adjusted, nasser, picasso, alessandro,
# Nearest to derived: reduplication, type, usages, traditionally, devoiced, arthur, form, phonological,
# Nearest to animals: mammals, humans, mammalia, nature, reptiles, inspection, species, article,
# Nearest to award: nominations, awards, awarded, oscars, emmy, impoverished, globe, curit,
# Nearest to applied: distract, greenfield, afips, embodied, sejm, bilinear, infirm, describe,
# Nearest to additional: theorizes, preparation, delocalised, computation, learn, miscible, raja, cuon,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9850 0.0292 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0047 0.0284 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 4.0021 0.0283 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0114 0.0284 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0927 0.0282 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9870 0.0282 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0187 0.0284 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0071 0.0287 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0224 0.0283 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0229 0.0282 sec/batch
# Nearest to years: migrant, zero, expectancy, female, january, male, birth, live,
# Nearest to had: was, bormann, colom, soon, glasgow, hoped, outfield, trajkovski,
# Nearest to these: companionate, accelerations, suggestibility, seeks, brushing, ambience, noteworthy, phase,
# Nearest to all: evangelium, is, modicum, surround, fledgling, not, consigned, caput,
# Nearest to most: inx, radically, raya, istrian, presidentially, alphabetical, rstendamm, abbreviated,
# Nearest to so: paraphrased, if, doesn, know, get, i, must, boil,
# Nearest to this: to, on, tin, designating, precision, their, with, accumulated,
# Nearest to states: united, ratisbon, demands, dt, pundit, amendment, ixian, u,
# Nearest to police: menelik, apolitical, department, ranatunga, excuse, regiments, mahuad, spouses,
# Nearest to brother: widower, soon, sister, applause, honeybee, blyton, smitten, mabon,
# Nearest to paris: expressionist, de, tulsa, mapmaker, ou, carabineros, alessandro, nasser,
# Nearest to derived: reduplication, type, usages, devoiced, traditionally, arthur, form, etymology,
# Nearest to animals: mammals, humans, mammalia, nature, reptiles, inspection, article, testes,
# Nearest to award: nominations, awards, awarded, oscars, globe, curit, emmy, impoverished,
# Nearest to applied: embodied, distract, thermionic, greenfield, describe, afips, engineer, bilinear,
# Nearest to additional: theorizes, computation, preparation, delocalised, require, learn, gprs, cuon,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0255 0.0295 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0249 0.0282 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0000 0.0284 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0196 0.0282 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0519 0.0282 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0263 0.0283 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9926 0.0284 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9644 0.0286 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9838 0.0283 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0583 0.0284 sec/batch
# Nearest to years: zero, migrant, expectancy, female, live, january, birth, male,
# Nearest to had: was, his, later, soon, bormann, hoped, colom, trajkovski,
# Nearest to these: companionate, suggestibility, noteworthy, seeks, accelerations, ambience, brushing, glimpses,
# Nearest to all: evangelium, is, modicum, surround, are, not, to, fledgling,
# Nearest to most: radically, mainstream, inx, governed, presidentially, notably, saarc, vodun,
# Nearest to so: if, get, soil, that, paraphrased, must, know, drags,
# Nearest to this: to, tin, with, on, precision, accumulated, reorient, designating,
# Nearest to states: united, demands, ratisbon, rehnquist, u, amendment, dt, critiques,
# Nearest to police: menelik, apolitical, department, ranatunga, regiments, excuse, mahuad, offeror,
# Nearest to brother: widower, sister, soon, blyton, smitten, honeybee, digging, applause,
# Nearest to paris: expressionist, de, tulsa, mapmaker, ou, carabineros, picasso, nasser,
# Nearest to derived: reduplication, type, usages, devoiced, form, etymology, traditionally, aes,
# Nearest to animals: mammals, humans, mammalia, nature, reptiles, inspection, testes, herbivores,
# ...
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8635 0.0282 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8573 0.0281 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8895 0.0283 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9494 0.0282 sec/batch
# Nearest to years: zero, live, migrant, age, six, female, over, birth,
# Nearest to had: was, later, did, would, soon, until, couldn, he,
# Nearest to these: several, because, different, noteworthy, and, well, companionate, known,
# Nearest to all: as, is, in, are, to, and, for, the,
# Nearest to most: notably, similar, also, have, than, some, are, even,
# Nearest to so: get, doesn, learns, that, if, rigidly, getting, snegur,
# Nearest to this: to, on, and, a, is, the, for, accumulated,
# Nearest to states: united, u, state, virginia, amendment, us, among, lincoln,
# Nearest to police: department, apolitical, subway, offeror, manpower, mahuad, capitulate, truck,
# Nearest to brother: sister, widower, soon, honeybee, deirdre, father, bundys, blyton,
# Nearest to paris: picasso, expressionist, ou, montparnasse, louvre, ticker, france, pour,
# Nearest to derived: type, etymology, reduplication, arthur, form, implements, wholeheartedly, dde,
# Nearest to animals: humans, mammals, pets, nature, mammalia, zoological, superior, stag,
# Nearest to award: awards, nominations, oscars, globe, awarded, winners, academy, nominated,
# Nearest to applied: engineer, afips, describe, biometric, embodied, interdisciplinary, greenfield, posthumus,
# Nearest to additional: theorizes, preparation, cosmetic, gprs, letter, computation, delocalised, till,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8432 0.0290 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8914 0.0285 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.9003 0.0286 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8724 0.0281 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8613 0.0280 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8899 0.0284 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8691 0.0283 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8837 0.0282 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8776 0.0285 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.9155 0.0286 sec/batch
# Nearest to years: zero, six, live, migrant, female, birth, over, age,
# Nearest to had: was, later, until, would, soon, he, his, were,
# Nearest to these: several, well, noteworthy, different, between, because, within, ratites,
# Nearest to all: as, is, are, in, same, to, and, for,
# Nearest to most: notably, similar, also, such, some, have, even, than,
# Nearest to so: get, that, doesn, if, snegur, learns, to, rigidly,
# Nearest to this: to, on, and, a, is, the, with, by,
# Nearest to states: united, u, amendment, state, us, virginia, encroach, rehnquist,
# Nearest to police: apolitical, department, manpower, subway, offeror, officer, capitulate, mahuad,
# Nearest to brother: sister, widower, soon, father, deirdre, blyton, wife, honeybee,
# Nearest to paris: picasso, montparnasse, expressionist, ou, france, louvre, ticker, carabineros,
# Nearest to derived: etymology, form, reduplication, type, arthur, usages, wholeheartedly, word,
# Nearest to animals: humans, mammals, pets, zoological, mammalia, nature, stag, superior,
# Nearest to award: awards, nominations, awarded, globe, oscars, academy, winners, best,
# Nearest to applied: engineer, posthumus, greenfield, biometric, interdisciplinary, embodied, seagull, tool,
# Nearest to additional: theorizes, preparation, gprs, delocalised, cosmetic, computation, letter, stress,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8690 0.0297 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8473 0.0284 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8603 0.0285 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8586 0.0282 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9317 0.0284 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8564 0.0286 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9918 0.0286 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9086 0.0284 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9149 0.0285 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8394 0.0283 sec/batch
# Nearest to years: zero, six, female, birth, live, migrant, male, age,
# Nearest to had: was, later, to, soon, would, until, his, did,
# Nearest to these: several, different, noteworthy, and, between, well, of, particularly,
# Nearest to all: as, in, are, is, same, and, the, to,
# Nearest to most: notably, such, also, some, similar, than, are, even,
# Nearest to so: get, that, if, snegur, doesn, getting, learns, tell,
# Nearest to this: to, on, and, a, is, the, by, for,
# Nearest to states: united, u, us, amendment, virginia, state, nominees, among,
# Nearest to police: department, apolitical, manpower, officer, subway, enforcement, capitulate, offeror,
# Nearest to brother: sister, widower, soon, father, blyton, graduated, honeybee, younger,
# Nearest to paris: picasso, montparnasse, ou, louvre, expressionist, france, chevalier, ticker,
# Nearest to derived: etymology, reduplication, type, arthur, word, inflect, usages, wholeheartedly,
# Nearest to animals: humans, pets, mammals, mammalia, nature, zoological, stag, superior,
# Nearest to award: awards, nominations, awarded, globe, oscars, winners, academy, nominated,
# Nearest to applied: engineer, posthumus, interdisciplinary, barlaam, retractable, seagull, afips, tool,
# Nearest to additional: theorizes, preparation, till, letter, delocalised, cosmetic, gprs, renovation,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7968 0.0290 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8499 0.0283 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8146 0.0287 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8844 0.0287 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8863 0.0281 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8863 0.0282 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8693 0.0189 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8572 0.0282 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8184 0.0283 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8709 0.0285 sec/batch
# Nearest to years: zero, migrant, live, birth, age, female, male, six,
# Nearest to had: was, would, to, he, later, did, until, his,
# Nearest to these: several, well, different, noteworthy, are, and, between, often,
# Nearest to all: as, in, is, are, the, and, to, for,
# Nearest to most: also, such, notably, are, some, have, than, similar,
# Nearest to so: that, to, get, snegur, doesn, learns, courtenay, boreal,
# Nearest to this: on, a, to, and, the, with, accumulated, is,
# Nearest to states: united, u, state, us, amendment, virginia, nominees, maryland,
# Nearest to police: apolitical, department, manpower, subway, enforcement, capitulate, offeror, officer,
# Nearest to brother: sister, father, widower, soon, younger, graduated, dowager, blyton,
# Nearest to paris: picasso, france, ou, expressionist, montparnasse, louvre, ticker, chevalier,
# Nearest to derived: etymology, reduplication, type, arthur, wholeheartedly, which, word, form,
# Nearest to animals: humans, pets, mammals, superior, zoological, nature, mammalia, stag,
# Nearest to award: awards, nominations, globe, awarded, oscars, academy, nominated, winners,
# Nearest to applied: posthumus, engineer, barlaam, interdisciplinary, seagull, embodied, retractable, greenfield,
# Nearest to additional: theorizes, preparation, cosmetic, delocalised, gprs, placename, till, computation,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8306 0.0295 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8584 0.0286 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8340 0.0286 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8771 0.0283 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8659 0.0282 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8433 0.0283 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8962 0.0283 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7304 0.0284 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8554 0.0287 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7922 0.0282 sec/batch
# Nearest to years: zero, migrant, live, age, female, six, three, birth,
# Nearest to had: was, later, would, until, never, did, soon, early,
# Nearest to these: several, different, well, and, are, of, noteworthy, known,
# Nearest to all: in, is, as, are, and, to, the, a,
# Nearest to most: also, notably, are, such, and, have, similar, some,
# Nearest to so: that, to, get, if, be, i, doesn, homeomorphisms,
# Nearest to this: to, and, on, a, the, is, for, that,
# Nearest to states: united, u, us, amendment, state, encroach, maryland, among,
# Nearest to police: department, apolitical, manpower, enforcement, subway, officer, offeror, capitulate,
# Nearest to brother: sister, widower, father, soon, graduated, honeybee, midland, deirdre,
# Nearest to paris: montparnasse, picasso, expressionist, ou, france, louvre, carabineros, ticker,
# Nearest to derived: type, etymology, reduplication, arthur, which, word, wholeheartedly, dde,
# Nearest to animals: humans, pets, mammals, superior, nature, zoological, inspection, mammalia,
# Nearest to award: awards, nominations, awarded, oscars, globe, academy, winners, nominated,
# Nearest to applied: engineer, posthumus, interdisciplinary, barlaam, embodied, afips, retractable, tool,
# Nearest to additional: theorizes, preparation, letter, computation, till, cosmetic, delocalised, gprs,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.8016 0.0292 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8391 0.0283 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8975 0.0281 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8184 0.0286 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8536 0.0282 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9140 0.0282 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8333 0.0284 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8286 0.0282 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8587 0.0284 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8462 0.0286 sec/batch
# Nearest to years: zero, female, migrant, birth, live, six, over, male,
# Nearest to had: was, later, would, until, did, early, soon, never,
# Nearest to these: several, different, well, and, often, known, are, of,
# Nearest to all: in, is, are, as, and, a, the, for,
# Nearest to most: notably, also, such, similar, and, have, are, some,
# Nearest to so: that, get, simplest, getting, doesn, be, snegur, homeomorphisms,
# Nearest to this: to, a, and, on, is, the, for, with,
# Nearest to states: united, u, amendment, us, encroach, state, virginia, directx,
# Nearest to police: department, apolitical, enforcement, manpower, officer, subway, convictions, offeror,
# Nearest to brother: sister, widower, father, soon, graduated, deirdre, younger, midland,
# Nearest to paris: montparnasse, france, ou, picasso, expressionist, louvre, carabineros, odeon,
# Nearest to derived: etymology, reduplication, type, word, arthur, wholeheartedly, form, dde,
# Nearest to animals: humans, pets, mammals, superior, zoological, mammalia, inspection, nature,
# Nearest to award: awards, nominations, awarded, oscars, globe, winners, nominated, academy,
# Nearest to applied: engineer, interdisciplinary, describe, barlaam, posthumus, embodied, biometric, tool,
# Nearest to additional: theorizes, preparation, the, computation, gprs, placename, generally, preamplifier,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8669 0.0293 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8768 0.0283 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8417 0.0284 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8607 0.0291 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8836 0.0284 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8751 0.0281 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8491 0.0280 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8522 0.0282 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8294 0.0284 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8276 0.0284 sec/batch
# Nearest to years: zero, female, live, six, over, birth, three, male,
# Nearest to had: was, later, would, did, to, never, early, until,
# Nearest to these: several, from, and, as, well, different, of, often,
# Nearest to all: in, as, is, are, the, to, and, a,
# Nearest to most: notably, such, and, also, similar, some, are, have,
# Nearest to so: that, get, to, if, not, will, be, getting,
# Nearest to this: to, and, a, the, on, is, of, that,
# Nearest to states: united, u, us, encroach, amendment, of, directx, see,
# Nearest to police: apolitical, department, enforcement, manpower, officer, subway, convictions, paramilitary,
# Nearest to brother: sister, widower, father, soon, graduated, younger, deirdre, his,
# Nearest to paris: montparnasse, france, ou, picasso, carabineros, chevalier, expressionist, ticker,
# Nearest to derived: etymology, reduplication, type, form, which, word, arthur, wholeheartedly,
# Nearest to animals: humans, pets, mammals, superior, zoological, mammalia, stag, mollusks,
# Nearest to award: awards, nominations, awarded, oscars, winners, globe, nominated, pulitzer,
# Nearest to applied: posthumus, barlaam, engineer, interdisciplinary, tool, embodied, describe, retractable,
# Nearest to additional: theorizes, preparation, by, placename, the, computation, letter, meigs,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8495 0.0295 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8778 0.0283 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9493 0.0283 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9093 0.0281 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9047 0.0282 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8024 0.0281 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7803 0.0283 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8566 0.0284 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7686 0.0282 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8916 0.0283 sec/batch
# Nearest to years: zero, female, male, live, birth, migrant, six, over,
# Nearest to had: was, later, would, did, until, soon, never, to,
# Nearest to these: several, and, well, as, of, from, different, were,
# Nearest to all: in, as, are, the, is, and, to, same,
# Nearest to most: notably, also, are, such, some, and, similar, than,
# Nearest to so: that, get, to, getting, tell, not, doesn, snegur,
# Nearest to this: to, on, and, a, the, is, that, for,
# Nearest to states: united, u, us, state, amendment, virginia, encroach, first,
# Nearest to police: department, apolitical, enforcement, subway, officer, manpower, convictions, capitulate,
# Nearest to brother: sister, widower, father, soon, younger, graduated, midland, his,
# Nearest to paris: montparnasse, france, picasso, ou, chevalier, odeon, ticker, expressionist,
# Nearest to derived: etymology, arthur, type, reduplication, word, wholeheartedly, jutish, which,
# Nearest to animals: humans, pets, mammals, superior, mammalia, nature, stag, zoological,
# Nearest to award: awards, nominations, awarded, globe, oscars, winners, nominated, academy,
# Nearest to applied: engineer, interdisciplinary, barlaam, posthumus, retractable, bilinear, afips, tool,
# Nearest to additional: theorizes, preparation, placename, till, letter, by, c, judah,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8458 0.0293 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8546 0.0282 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
# Out:
# /home/ubuntu/anaconda3/envs/embedding_dlnd/lib/python3.6/site-packages/matplotlib/__init__.py:1085: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/embedding_dlnd/lib/python3.6/site-packages/matplotlib/__init__.py:1085: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
